# %%
#Ejemplo format
'Un {} vale {} {}'.format('€', 1.12, '$')
# Out:
# 'Un € vale 1.12 $'

# %%
 'Un {2} vale {1} {0}'.format('€', 1.12, '$')
# Out:
# 'Un $ vale 1.12 €'

# %%
#conversion de tipos de datos
int('12')#convierto una cadenba a entero
str('1234')
# Out:
# '1234'

# %%
#entrada por terminal: input()
strlenguaje = input('Que lenguaje te gusta mas')
# Out:
# Que lenguaje te gusta mas e

# %%
#valor devuelto por input
x=input('damew un numero')
y=input('dame otro numero')
z= x + y
print(z)
# Out:
# damew un numero 3
# dame otro numero 4
# 34

# %%
#valor devuelto por input(integer)
x=int(input('damew un numero'))
y=int(input('dame otro numero'))
z= x + y
print(z)
# Out:
# damew un numero 3
# dame otro numero 4
# 7

# %%
#condicionales con if, elif, else
edad= int(input('dime tu edad'))
if (edad<18):
    print('Menor de Edad')
elif(edad>=18 and edad <65):
    print('en edad de trabajador')
else:
    print('esta jubilado')
    print('por fin')
# Out:
# dime tu edad 89
# esta jubilado
# por fin

# %%
# Pregunta al usuario por un número hasta que introduce 0.
while True:
    num = int(input('Introduce un número: '))
    if num == 0:
    break
# Out:
# Introduce un número:  1
# Introduce un número:  2
# Introduce un número:  3
# Introduce un número:  4
# Introduce un número:  5
# Introduce un número:  6
# Introduce un número:  7
# Introduce un número:  8
# Introduce un número:  9
# Introduce un número:  0

# %%
#esto ejecuta del 0-9
i=0
while (i <10):
    i+=1
    print(i):
    if i>5:
    break
# Out:
#   Cell In[45], line 5
#     print(i):
#             ^
# SyntaxError: invalid syntax

# %%
#esto ejecuta del 0-9
i=0
while (i <10):
    i+=1
    print(i):
        if i>10:
        break
# Out:
# 1
# 2
# 3
# 4
